# %%
import pandas as pd
import plotly.express as px
import numpy as np

# %%
dg_proj_copy = pd.DataFrame(round(dg_proj_copy[['dk_name','dk_salary','total_points','value','projected_ownership']],2)).sort_values(by='dk_salary',ascending=False).reset_index(drop=True)
st.dataframe(dg_proj_copy.round(2).style.background_gradient(subset=['value'],cmap='Greys').format(precision=2),
             hide_index=True,
             height=1000,
             column_config={
                  'dk_name':'Name',
                  'dk_salary': st.column_config.NumberColumn(
                       'DK Salary',
                       format = "$ %.0f"
                    ),
                #    'early_late_wave':'Early/Late Wave',
                   'total_points':'Proj Pts',
                   'value': 'Value',
                   'projected_ownership':'pOwn',
                   'adj_from_baseline': 'Baseline Adj'
             },
             use_container_width=True
        )

# %%
dg_proj = pd.read_csv(f"https://feeds.datagolf.com/preds/fantasy-projection-defaults?tour=pga&site=draftkings&slate=main&file_format=csv&key=e297e933c3ad47d71ec1626c299e")
# dg_proj = dg_proj[['player_name','proj_points_total']]
dg_proj
# Out:
#     tour               event_name             last_updated        site slate  \
# 0    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 1    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 2    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 3    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 4    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# ..   ...                      ...                      ...         ...   ...
# 151  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 152  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 153  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 154  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 155  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
#
#                player_name  dg_id                     site_name_id r1_teetime  \
# 0                 Kim, Tom  24766               Tom Kim (34772545)    7:40 am
# 1           Young, Cameron  26651         Cameron Young (34772546)    7:40 am
# 2             Lee, Min Woo  16841           Min Woo Lee (34772547)   12:43 pm
# 3              Noren, Alex  10419            Alex Noren (34772548)    8:02 am
# 4           Bhatia, Akshay  26096         Akshay Bhatia (34772549)   12:43 pm
# ..                     ...    ...                              ...        ...
# 151  Giantsopoulos, Angelo  30203  Angelo Giantsopoulos (34785267)    8:57 am
# 152           Martin, Kyle  31284           Kyle Martin (34772695)    2:22 pm
# 153           Pereda, Raul  19620           Raul Pereda (34772696)    2:22 pm
# 154        James, Benjamin  29827        Benjamin James (34772690)    8:57 am
# 155      Albertson, Anders  21235      Anders Albertson (34772688)    2:22 pm
#
#      early_late_wave  salary  proj_points_total  proj_points_scoring  \
# 0                  1   11000              84.79                77.62
# 1                  1   10700              75.64                70.59
# 2                  0   10500              80.50                74.31
# 3                  1   10200              77.27                71.78
# 4                  0    9800              77.20                71.84
# ..               ...     ...                ...                  ...
# 151                1    5000               8.04                 8.04
# 152                0    5000              29.94                29.85
# 153                0    5000              32.10                31.97
# 154                1    5000              54.94                53.17
# 155                0    5000              38.78                38.39
#
#      proj_points_finish  proj_ownership
# 0                  7.17           24.21
# 1                  5.05           18.25
# 2                  6.19           23.22
# 3                  5.50           14.64
# 4                  5.36           19.50
# ..                  ...             ...
# 151                0.00            0.00
# 152                0.09            0.00
# 153                0.13            0.00
# 154                1.77            1.35
# 155                0.39            0.00
#
# [156 rows x 15 columns]

# %%
dg_proj.columns = ['player','proj_pts']
dg_proj
# Out:
#                  player  proj_pts
# 0         McIlroy, Rory     72.77
# 1     Matsuyama, Hideki     65.49
# 2         Aberg, Ludvig     69.36
# 3      Morikawa, Collin     65.09
# 4             Homa, Max     62.81
# ..                  ...       ...
# 151        Teater, Josh     36.23
# 152        Holmes, J.B.     28.94
# 153  Gutschewski, Scott     32.77
# 154       Sullivan, Joe     21.46
# 155         Welch, Alex     15.80
#
# [156 rows x 2 columns]

# %%
def fix_names(dg):
        names = dg['player'].str.split(expand=True)                  
        names[0] = names[0].str.rstrip(",")
        names[1] = names[1].str.rstrip(",")
        names['player'] = names[1] + " " + names[0]

        names['player'] = np.where(names['player']=='Matt Fitzpatrick', 'Matthew Fitzpatrick', names['player'])
        names['player'] = np.where(names['player']=='Si Kim', 'Si Woo Kim', names['player'])
        names['player'] = np.where(names['player']=='Min Lee', 'Min Woo Lee', names['player'])
        names['player'] = np.where(names['player']=='Byeong An', 'Byeong Hun An', names['player'])
        names['player'] = np.where(names['player']=='Rooyen Van', 'Erik Van Rooyen', names['player'])
        names['player'] = np.where(names['player']=='Vince Whaley', 'Vincent Whaley', names['player'])
        names['player'] = np.where(names['player']=='Kevin Yu', 'kevin Yu', names['player'])
        names['player'] = np.where(names['player']=='Kyounghoon Lee', 'Kyoung-Hoon Lee', names['player'])
        return names.player

# %%
dg_proj.set_index(fix_names(dg_proj),inplace=True)

# %%
dg_proj
# Out:
#                                player  proj_pts
# player
# Rory McIlroy            McIlroy, Rory     72.77
# Hideki Matsuyama    Matsuyama, Hideki     65.49
# Ludvig Aberg            Aberg, Ludvig     69.36
# Collin Morikawa      Morikawa, Collin     65.09
# Max Homa                    Homa, Max     62.81
# ...                               ...       ...
# Josh Teater              Teater, Josh     36.23
# J.B. Holmes              Holmes, J.B.     28.94
# Scott Gutschewski  Gutschewski, Scott     32.77
# Joe Sullivan            Sullivan, Joe     21.46
# Alex Welch                Welch, Alex     15.80
#
# [156 rows x 2 columns]

# %%
usecols=['Player','Status','Roster Status']

teams = pd.read_csv(r"C:\Users\mikej\Desktop\fantrax\week.csv",usecols=usecols)
teams
# Out:
#               Player Status Roster Status
# 0       Ludvig Aberg   NT 4        Active
# 1          Sam Burns   [AW]       Reserve
# 2    Patrick Cantlay    u_c        Active
# 3      Wyndham Clark     MG       Reserve
# 4          Eric Cole     MG        Active
# ..               ...    ...           ...
# 115    Adrian Meronk   grrr       Reserve
# 116    Ben Silverman   grrr        Active
# 117   Gordon Sargent   NT 8       Reserve
# 118  Jacob Bridgeman   [AW]       Reserve
# 119   Max Greyserman   grrr        Active
#
# [120 rows x 3 columns]

# %%
teams_dict = {
        '919':'Philly919',
        'u_c':'unit_circle',
        'NT 4':'New Team 4',
        'NT 8':'Sneads Foot',
        'txms':'txmoonshine',
        'MG':'Team Gamble',
        'grrr':'Putt Pirates',
        '[AW]':'AlphaWired'
        }

# %%
teams.columns = ['player','team','active_reserve']
teams['team'] = teams.team.map(teams_dict)
teams.set_index('player',inplace=True)
teams
# Out:
#                          team active_reserve
# player
# Ludvig Aberg       New Team 4         Active
# Sam Burns          AlphaWired        Reserve
# Patrick Cantlay   unit_circle         Active
# Wyndham Clark     Team Gamble        Reserve
# Eric Cole         Team Gamble         Active
# ...                       ...            ...
# Adrian Meronk    Putt Pirates        Reserve
# Ben Silverman    Putt Pirates         Active
# Gordon Sargent    Sneads Foot        Reserve
# Jacob Bridgeman    AlphaWired        Reserve
# Max Greyserman   Putt Pirates         Active
#
# [120 rows x 2 columns]

# %%
####   MERGE DATA    ####
week = pd.merge(teams,dg_proj, left_index=True, right_index=True)

week[['player','team','active_reserve']] = week[
    ['player','team','active_reserve']
    ].astype('string')

week.sort_values('proj_pts',ascending=False,inplace=True)

# %%
week
# Out:
#                             team active_reserve             player  proj_pts
# player
# Rory McIlroy         Sneads Foot         Active      McIlroy, Rory     72.77
# Ludvig Aberg          New Team 4         Active      Aberg, Ludvig     69.36
# Jordan Spieth         AlphaWired         Active     Spieth, Jordan     67.73
# Alex Noren           unit_circle        Reserve        Noren, Alex     66.34
# Matthew Fitzpatrick  txmoonshine         Active  Fitzpatrick, Matt     65.60
# ...                          ...            ...                ...       ...
# Cameron Champ        Sneads Foot        Reserve     Champ, Cameron     44.88
# Parker Coody         Sneads Foot        Reserve      Coody, Parker     44.21
# Brandon Wu            New Team 4         Active        Wu, Brandon     43.32
# Tyler Duncan           Philly919        Reserve      Duncan, Tyler     43.11
# Camilo Villegas       New Team 4        Reserve   Villegas, Camilo     35.57
#
# [71 rows x 4 columns]

# %%
dg_proj
# Out:
#     tour               event_name             last_updated        site slate  \
# 0    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 1    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 2    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 3    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 4    pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# ..   ...                      ...                      ...         ...   ...
# 151  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 152  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 153  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 154  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
# 155  pga  Rocket Mortgage Classic  2024-06-26 13:53:38 UTC  draftkings  main
#
#                player_name  dg_id                     site_name_id r1_teetime  \
# 0                 Kim, Tom  24766               Tom Kim (34772545)    7:40 am
# 1           Young, Cameron  26651         Cameron Young (34772546)    7:40 am
# 2             Lee, Min Woo  16841           Min Woo Lee (34772547)   12:43 pm
# 3              Noren, Alex  10419            Alex Noren (34772548)    8:02 am
# 4           Bhatia, Akshay  26096         Akshay Bhatia (34772549)   12:43 pm
# ..                     ...    ...                              ...        ...
# 151  Giantsopoulos, Angelo  30203  Angelo Giantsopoulos (34785267)    8:57 am
# 152           Martin, Kyle  31284           Kyle Martin (34772695)    2:22 pm
# 153           Pereda, Raul  19620           Raul Pereda (34772696)    2:22 pm
# 154        James, Benjamin  29827        Benjamin James (34772690)    8:57 am
# 155      Albertson, Anders  21235      Anders Albertson (34772688)    2:22 pm
#
#      early_late_wave  salary  proj_points_total  proj_points_scoring  \
# 0                  1   11000              84.79                77.62
# 1                  1   10700              75.64                70.59
# 2                  0   10500              80.50                74.31
# 3                  1   10200              77.27                71.78
# 4                  0    9800              77.20                71.84
# ..               ...     ...                ...                  ...
# 151                1    5000               8.04                 8.04
# 152                0    5000              29.94                29.85
# 153                0    5000              32.10                31.97
# 154                1    5000              54.94                53.17
# 155                0    5000              38.78                38.39
#
#      proj_points_finish  proj_ownership
# 0                  7.17           24.21
# 1                  5.05           18.25
# 2                  6.19           23.22
# 3                  5.50           14.64
# 4                  5.36           19.50
# ..                  ...             ...
# 151                0.00            0.00
# 152                0.09            0.00
# 153                0.13            0.00
# 154                1.77            1.35
# 155                0.39            0.00
#
# [156 rows x 15 columns]

# %%
px.scatter(dg_proj,
          y='proj_points_total',
          x='proj_ownership',
          log_x=True,
#           log_y=True,
          trendline='lowess',
          color='salary',
          hover_name='player_name',
          template='presentation')
# Out:
# <div>                            <div id="5cf281b5-6531-451b-8874-b85a34dd23c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5cf281b5-6531-451b-8874-b85a34dd23c6")) {                    Plotly.newPlot(                        "5cf281b5-6531-451b-8874-b85a34dd23c6",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>proj_ownership=%{x}<br>proj_points_total=%{y}<br>salary=%{marker.color}<extra></extra>","hovertext":["Kim, Tom","Young, Cameron","Lee, Min Woo","Noren, Alex","Bhatia, Akshay","Pendrith, Taylor","Jaeger, Stephan","Zalatoris, Will","Fowler, Rickie","McNealy, Maverick","Rai, Aaron","Macintyre, Robert","Mitchell, Keith","Thompson, Davis","Fox, Ryan","Kirk, Chris","Thorbjornsen, Michael","Griffin, Ben","Van Rooyen, Erik","Hubbard, Mark","Svensson, Adam","Rodgers, Patrick","Moore, Taylor","Dunlap, Nick","Wallace, Matt","Hossler, Beau","Hojgaard, Nicolai","Davis, Cameron","Stevens, Samuel","Hodges, Lee","Yu, Kevin","Cole, Eric","Berger, Daniel","Clanton, Luke","Hisatsune, Ryo","Olesen, Thorbjorn","Ghim, Doug","Schenk, Adam","Montgomery, Taylor","Riley, Davis","Todd, Brendon","Novak, Andrew","Phillips, Chandler","Gotterup, Chris","List, Luke","Kim, Michael","Tosti, Alejandro","Vegas, Jhonattan","Koivun, Jackson","Schmid, Matthias","Sigg, Greyson","Lower, Justin","Simpson, Webb","Lashley, Nate","Meissner, Mac","Spaun, J.J.","Kim, Seonghyeon","Lee, Kyounghoon","Knapp, Jake","Kim, Chan","Merritt, Troy","Hadley, Chesson","Shipley, Neal","Bridgeman, Jacob","Greyserman, Max","Smalley, Alex","Hoffman, Charley","Bramlett, Joseph","Champ, Cameron","Pan, C.T.","Woodland, Gary","Skinns, David","Malnati, Peter","Whaley, Vince","Dahmen, Joel","Kuchar, Matt","Duncan, Tyler","Campillo, Jorge","Tway, Kevin","Cauley, Bud","Kohles, Ben","Silverman, Ben","Young, Carson","Coody, Pierceson","Coody, Parker","Garnett, Brice","Laird, Martin","Valimaki, Sami","Higgo, Garrick","Hardy, Nick","Ryder, Sam","Kizzire, Patton","Fishburn, Patrick","Wu, Dylan","Ramey, Chad","Kraft, Kelly","Cink, Stewart","Hall, Harry","Suh, Justin","Crowe, Trace","Norlander, Henrik","Griffin, Lanto","Yuan, Carl","Shelton, Robby","Dumont de Chassart, Adrien","Moore, Ryan","Dougherty, Kevin","NeSmith, Matthew","Streelman, Kevin","Johnson, Zach","Norrman, Vincent","Blair, Zac","Highsmith, Joe","Hoey, Rico","Lipsky, David","Reavie, Chez","Wu, Brandon","Buckley, Hayden","Springer, Hayden","Echavarria, Nicolas","McCormick, Ryan","Baddeley, Aaron","Barnes, Erik","Tarren, Callum","Furr, Wilson","Campos, Rafael","Molinari, Francesco","Alexander, Tyson","Trainer, Martin","Teater, Josh","Sloan, Roger","Lindheim, Nicholas","Barjon, Paul","Endycott, Harrison","Bryan, Wesley","Berry, Brandon","Wilkinson, Tim","Walker, Jimmy","Russell, Miles","Guise, Danny","Kisner, Kevin","Brehm, Ryan","Dufner, Jason","Villegas, Camilo","Whitney, Tom","Bienz, Nick","Mack III, Willie","Gutschewski, Scott","Snedeker, Brandt","Taylor, Ben","Hale Jr, Blaine","Giantsopoulos, Angelo","Martin, Kyle","Pereda, Raul","James, Benjamin","Albertson, Anders"],"legendgroup":"","marker":{"color":[11000,10700,10500,10200,9800,9600,9400,9200,9000,8900,8800,8700,8500,8300,8200,8100,8000,7900,7800,7700,7600,7500,7500,7400,7400,7300,7300,7200,7200,7100,7100,7000,7000,7000,6900,6900,6900,6800,6800,6800,6700,6700,6700,6700,6600,6600,6600,6600,6600,6500,6500,6500,6500,6500,6400,6400,6400,6400,6400,6300,6300,6300,6300,6300,6200,6200,6200,6200,6200,6200,6100,6100,6100,6100,6100,6100,6000,6000,6000,6000,6000,6000,5900,5900,5900,5900,5900,5900,5800,5800,5800,5800,5800,5800,5700,5700,5700,5700,5700,5700,5600,5600,5600,5600,5600,5600,5500,5500,5500,5500,5500,5500,5500,5400,5400,5400,5400,5400,5400,5400,5300,5300,5300,5300,5300,5300,5300,5200,5200,5200,5200,5200,5200,5200,5200,520 ...
