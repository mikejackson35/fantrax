# %%
import pandas as pd

# %%
leaderboard = pd.read_html(r"https://results.golfstat.com/public/leaderboards/gsnav.cfm?pg=player&tid=28713")
leaderboard
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 leaderboard = pd.read_html(r"https://results.golfstat.com/public/leaderboards/gsnav.cfm?pg=player&tid=28713")
#       2 leaderboard
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# ...

# %%
## Full Xpath
/html/body/div[2]/div/div/div/div[4]/div/div[1]/div[3]/a

## xpath
/html/body/div[2]/div/div/div/div[4]/div/div[1]/div[3]/a

## copy styles
    font-size: .9em;
    white-space: nowrap;
    text-align: left;
    font-family: Arial, Helvetica, sans-serif;
    TEXT-DECORATION: none;
    color: #000066;

# copy js path
document.querySelector("body > div:nth-child(3) > div > div > div > div:nth-child(4) > div > div:nth-child(1) > div:nth-child(3) > a")

# copy selector
body > div:nth-child(3) > div > div > div > div:nth-child(4) > div > div:nth-child(1) > div:nth-child(3) > a
                
#  outer html
<div style="display:inline-block;background-color:#ffffff;border:0px solid blue;padding:5px; white-space:nowrap;">
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">1</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Michael Senn" onclick="getScorecard(28713,3,394125,'05643A',0)">Michael Senn</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Belmont 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
-1 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>68</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player394125" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">2</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Pablo Riveiro" onclick="getScorecard(28713,3,411394,'05643A',0)">Pablo Riveiro</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Chicago State Univ. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
E 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411394" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T3</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Jackson Davenport" onclick="getScorecard(28713,3,382515,'05643A',0)">Jackson Davenport</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								West Virginia 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+1 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								10 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>71</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>72</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player382515" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T3</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Wyatt Brackett" onclick="getScorecard(28713,3,399885,'05643A',0)">Wyatt Brackett</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+1 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player399885" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T5</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Olivier Menard" onclick="getScorecard(28713,3,382517,'05643A',0)">Olivier Menard</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								West Virginia 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+2 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								10 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>72</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player382517" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T5</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Jace Day" onclick="getScorecard(28713,3,381524,'05643A',0)">Jace Day</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Southern Indiana 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+2 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>71</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player381524" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T5</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Haden Maxwell" onclick="getScorecard(28713,3,399472,'05643A',0)">Haden Maxwell</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+2 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player399472" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T8</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 11 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Brody Simms" onclick="getScorecard(28713,3,401002,'05643A',0)">Brody Simms</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Cleveland State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+3 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								8 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>71</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player401002" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T8</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Nolan Piazza" onclick="getScorecard(28713,3,390208,'05643A',0)">Nolan Piazza</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Morehead State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+3 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								1 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>69</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player390208" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T10</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Carter Goebel" onclick="getScorecard(28713,3,399306,'05643A',0)">Carter Goebel</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Southern Indiana 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+4 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>71</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player399306" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T10</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Trey Melvin" onclick="getScorecard(28713,3,379784,'05643A',0)">Trey Melvin</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+4 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player379784" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T10</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Jack Schoenberger" onclick="getScorecard(28713,3,400461,'05643A',0)">Jack Schoenberger</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Belmont 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+4 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player400461" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T10</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Jason Bannister" onclick="getScorecard(28713,3,388733,'05643A',0)">Jason Bannister</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Southern Indiana 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+4 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>69</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player388733" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T10</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Jack Darke" onclick="getScorecard(28713,3,411346,'05643A',0)">Jack Darke</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Belmont 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+4 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411346" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T15</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Miles Parroco" onclick="getScorecard(28713,3,391904,'05643A',0)">Miles Parroco</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Northern Kentucky 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+5 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player391904" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T15</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Oliver Lewis-Perkins" onclick="getScorecard(28713,3,379786,'05643A',0)">Oliver Lewis-Perkins</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+5 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>71</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player379786" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T17</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 7 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Conner Brown" onclick="getScorecard(28713,3,400460,'05643A',0)">Conner Brown</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Belmont 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+6 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>72</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player400460" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T17</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Bennett McNabb" onclick="getScorecard(28713,3,393702,'05643A',0)">Bennett McNabb</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+6 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>70</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player393702" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T17</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Reeve Felner" onclick="getScorecard(28713,3,382144,'05643A',0)">Reeve Felner</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Belmont 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+6 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player382144" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T17</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 5 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Anders Larson" onclick="getScorecard(28713,3,399471,'05643A',0)">Anders Larson</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+6 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player399471" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T21</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 6 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Westy McCabe" onclick="getScorecard(28713,3,399347,'05643A',0)">Westy McCabe</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								West Virginia 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+7 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								10 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player399347" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T21</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 6 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Logan Liles" onclick="getScorecard(28713,3,400565,'05643A',0)">Logan Liles</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Morehead State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+7 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>71</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player400565" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T23</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 9 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Mark McDearman" onclick="getScorecard(28713,3,380517,'05643A',0)">Mark McDearman</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+8 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player380517" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T23</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Sean Anderson" onclick="getScorecard(28713,3,371723,'05643A',0)">Sean Anderson</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+8 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player371723" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T23</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 4 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Pongbhop Jamornsrianan" onclick="getScorecard(28713,3,379659,'05643A',0)">P. Jamornsrianan…</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Delta State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+8 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								1 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>72</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player379659" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T26</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 7 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Mason Sokolowski" onclick="getScorecard(28713,3,411400,'05643A',0)">Mason Sokolowski</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Detroit Mercy 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+9 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								8 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>72</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411400" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T26</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Ryan Mitts" onclick="getScorecard(28713,3,373904,'05643A',0)">Ryan Mitts</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Northern Kentucky 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+9 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>71</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player373904" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T26</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 8 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Frankie Morgan" onclick="getScorecard(28713,3,392091,'05643A',0)">Frankie Morgan</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Bellarmine 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+9 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player392091" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T26</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 4 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Carson Parker" onclick="getScorecard(28713,3,384106,'05643A',0)">Carson Parker</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Evansville 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+9 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>72</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player384106" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 19 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="George Cordall" onclick="getScorecard(28713,3,410284,'05643A',0)">George Cordall</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>83</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>72</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player410284" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Andrew Kaye" onclick="getScorecard(28713,3,382895,'05643A',0)">Andrew Kaye</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Cleveland State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player382895" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 8 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Mason Frazier" onclick="getScorecard(28713,3,382896,'05643A',0)">Mason Frazier</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Cleveland State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player382896" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Julian Colavecchia" onclick="getScorecard(28713,3,394515,'05643A',0)">Julian Colavecchia</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Chicago State Univ. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player394515" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 8 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Luke Muller" onclick="getScorecard(28713,3,391980,'05643A',0)">Luke Muller</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Northern Kentucky 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player391980" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 8 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Purin Yingpisit" onclick="getScorecard(28713,3,401186,'05643A',0)">Purin Yingpisit</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Delta State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player401186" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 4 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="King Grisanti" onclick="getScorecard(28713,3,411386,'05643A',0)">King Grisanti</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Delta State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411386" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T30</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 4 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Luke Bischoff" onclick="getScorecard(28713,3,399288,'05643A',0)">Luke Bischoff</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Bellarmine 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+10 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								1 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player399288" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T38</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Jackson Skeen" onclick="getScorecard(28713,3,389113,'05643A',0)">Jackson Skeen</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+11 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								4 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player389113" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T38</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 6 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Noah Ross" onclick="getScorecard(28713,3,410286,'05643A',0)">Noah Ross</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+11 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								4 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player410286" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T40</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 9 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Carson Kammann" onclick="getScorecard(28713,3,409945,'05643A',0)">Carson Kammann</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								West Virginia 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+12 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								10 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>86</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>69</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player409945" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T40</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Jared Southerland" onclick="getScorecard(28713,3,405463,'05643A',0)">Jared Southerland</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee State U. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+12 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player405463" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T42</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 7 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Carter Walton" onclick="getScorecard(28713,3,405465,'05643A',0)">Carter Walton</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee State U. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+13 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player405465" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T42</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Matt Nicell" onclick="getScorecard(28713,3,411150,'05643A',0)">Matt Nicell</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Delta State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+13 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411150" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T44</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 16 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Harrison Smith" onclick="getScorecard(28713,3,379785,'05643A',0)">Harrison Smith</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+14 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player379785" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T44</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Ben Seay" onclick="getScorecard(28713,3,379783,'05643A',0)">Ben Seay</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Lee University 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+14 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>74</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player379783" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T44</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 12 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Isaac Rohleder" onclick="getScorecard(28713,3,371748,'05643A',0)">Isaac Rohleder</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Evansville 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+14 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player371748" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T44</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 6 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Caleb Wassmer" onclick="getScorecard(28713,3,371750,'05643A',0)">Caleb Wassmer</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Evansville 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+14 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								5 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player371750" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T44</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 5 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Hudson Hummel" onclick="getScorecard(28713,3,392092,'05643A',0)">Hudson Hummel</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Bellarmine 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+14 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>73</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>82</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player392092" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T44</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 6 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Samuel Boddie" onclick="getScorecard(28713,3,411697,'05643A',0)">Samuel Boddie</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Alabama A&amp;M 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+14 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411697" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T50</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 6 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Devin Kucy" onclick="getScorecard(28713,3,411395,'05643A',0)">Devin Kucy</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Chicago State Univ. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+15 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411395" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T50</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 16 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Evan Stewart" onclick="getScorecard(28713,3,391905,'05643A',0)">Evan Stewart</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Northern Kentucky 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+15 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +5 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player391905" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T50</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Niko Salmi" onclick="getScorecard(28713,3,411149,'05643A',0)">Niko Salmi</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Delta State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+15 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								4 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411149" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T50</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 10 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Kash Albarado" onclick="getScorecard(28713,3,405294,'05643A',0)">Kash Albarado</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Bellarmine 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+15 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player405294" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T54</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 11 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Dillon Pendergast" onclick="getScorecard(28713,3,412055,'05643A',0)">Dillon Pendergast</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Cleveland State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+16 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player412055" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T54</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 11 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Alex Broyles" onclick="getScorecard(28713,3,412889,'05643A',0)">Alex Broyles</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+16 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player412889" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T54</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Trevor Laub" onclick="getScorecard(28713,3,407153,'05643A',0)">Trevor Laub</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Southern Indiana 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+16 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player407153" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T54</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Clay Wells" onclick="getScorecard(28713,3,394510,'05643A',0)">Clay Wells</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Chicago State Univ. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+16 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player394510" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T54</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 5 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Spencer McCranie" onclick="getScorecard(28713,3,411349,'05643A',0)">Spencer McCranie</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee State U. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+16 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411349" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T54</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 11 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Isaac Napier" onclick="getScorecard(28713,3,405464,'05643A',0)">Isaac Napier</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee State U. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+16 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								5 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player405464" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T54</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 6 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Logan McCormick" onclick="getScorecard(28713,3,400566,'05643A',0)">Logan McCormick</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Morehead State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+16 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								2 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player400566" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T61</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 12 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Alek Mauro" onclick="getScorecard(28713,3,386239,'05643A',0)">Alek Mauro</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Detroit Mercy 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+17 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player386239" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T61</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Isaac Moody" onclick="getScorecard(28713,3,411566,'05643A',0)">Isaac Moody</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Northern Kentucky 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+17 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411566" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T61</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Niall Bagnall" onclick="getScorecard(28713,3,403580,'05643A',0)">Niall Bagnall</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Alabama A&amp;M 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+17 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								5 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>82</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player403580" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T61</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 13 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Cameron Travis" onclick="getScorecard(28713,3,390205,'05643A',0)">Cameron Travis</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Morehead State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+17 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								3 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>83</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player390205" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T65</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 5 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Ben Scheeff" onclick="getScorecard(28713,3,412056,'05643A',0)">Ben Scheeff</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Cleveland State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+18 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player412056" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T65</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Valentin Cerdá" onclick="getScorecard(28713,3,399895,'05643A',0)">Valentin Cerdá</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Christian Brothers 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+18 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player399895" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T65</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Andres Rodriguez" onclick="getScorecard(28713,3,411401,'05643A',0)">Andres Rodriguez</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Evansville 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+18 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411401" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T65</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Augus Johnson" onclick="getScorecard(28713,3,412182,'05643A',0)">Augus Johnson</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Bellarmine 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+18 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								4 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player412182" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T69</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 9 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Hunter Reynolds" onclick="getScorecard(28713,3,413772,'05643A',0)">Hunter Reynolds</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Southern Indiana 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+19 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> -1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>85</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player413772" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T69</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 31 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Dominik Cosic" onclick="getScorecard(28713,3,412795,'05643A',0)">Dominik Cosic</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Cleveland State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+19 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +8 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player412795" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T71</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 5 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Marko Banic" onclick="getScorecard(28713,3,411398,'05643A',0)">Marko Banic</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Detroit Mercy 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+20 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411398" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T71</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Gowtham Nalluri" onclick="getScorecard(28713,3,411399,'05643A',0)">Gowtham Nalluri</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Detroit Mercy 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+20 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>83</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411399" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T71</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 4 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Alex Anderson" onclick="getScorecard(28713,3,401003,'05643A',0)">Alex Anderson</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Cleveland State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+20 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>75</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>83</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player401003" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T71</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 11 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Joe Bultman" onclick="getScorecard(28713,3,400462,'05643A',0)">Joe Bultman</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Belmont 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+20 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								4 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +5 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player400462" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T75</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Peyton Short" onclick="getScorecard(28713,3,378980,'05643A',0)">Peyton Short</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Southern Indiana 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+21 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>82</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player378980" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T75</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 8 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Micah Bertram" onclick="getScorecard(28713,3,415122,'05643A',0)">Micah Bertram</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Northern Kentucky 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+21 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +5 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player415122" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T77</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Alexian Rouault" onclick="getScorecard(28713,3,415121,'05643A',0)">Alexian Rouault</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Christian Brothers 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+22 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +2 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>84</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player415121" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T77</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 5 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Daniil Romashkin" onclick="getScorecard(28713,3,405870,'05643A',0)">Daniil Romashkin</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Evansville 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+22 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>81</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>82</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player405870" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T79</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Nathan London" onclick="getScorecard(28713,3,412778,'05643A',0)">Nathan London</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Christian Brothers 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+23 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>82</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player412778" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T79</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 3 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Avery Irwin" onclick="getScorecard(28713,3,389114,'05643A',0)">Avery Irwin</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+23 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>82</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player389114" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T79</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 12 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Alexander Bassel" onclick="getScorecard(28713,3,380516,'05643A',0)">Alexander Bassel</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee Tech 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+23 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +7 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player380516" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T79</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 12 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Hayden Morgan-Evens" onclick="getScorecard(28713,3,395958,'05643A',0)">Hayden Morgan-Evens</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Christian Brothers 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+23 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								8 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +7 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>78</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player395958" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">83</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Austin Brancaccio" onclick="getScorecard(28713,3,404986,'05643A',0)">Austin Brancaccio</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Detroit Mercy 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+24 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>89</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>76</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player404986" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">84</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Payton Dunahee" onclick="getScorecard(28713,3,394511,'05643A',0)">Payton Dunahee</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Chicago State Univ. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+25 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> E </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>87</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player394511" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">85</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Colin Armistead" onclick="getScorecard(28713,3,405376,'05643A',0)">Colin Armistead</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Chicago State Univ. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+28 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								10 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>83</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>83</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player405376" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">86</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 2 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Bo Twerdahl" onclick="getScorecard(28713,3,411350,'05643A',0)">Bo Twerdahl</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Tennessee State U. 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+29 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +5 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>79</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>87</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411350" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T87</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/moveup.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Andrew Marrs" onclick="getScorecard(28713,3,382754,'05643A',0)">Andrew Marrs</a>
								<div style="display:inline-block; position:relative; top:-3px; font-size:0.75em;padding:0px 5px 0px 1px;width:0.95em;">‡</div> 
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Morehead State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+30 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								10 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>88</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player382754" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">T87</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
									<img src="/images/movedown.png" align="absmiddle"> 1 
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Juan Rey" onclick="getScorecard(28713,3,407651,'05643A',0)">Juan Rey</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Alabama A&amp;M 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+30 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +5 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>80</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>87</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player407651" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">89</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="James Nichols" onclick="getScorecard(28713,3,382124,'05643A',0)">James Nichols</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Christian Brothers 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+32 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								9 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>82</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>88</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player382124" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">90</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Gage Flowers" onclick="getScorecard(28713,3,411700,'05643A',0)">Gage Flowers</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Alabama A&amp;M 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+34 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								6 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +3 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>85</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>88</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411700" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">91</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Kourey Patterson" onclick="getScorecard(28713,3,411698,'05643A',0)">Kourey Patterson</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Alabama A&amp;M 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
+39 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								7 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +4 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>85</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>92</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player411698" style="display:none;visibility:hidden;"></div>
					
						<div style="color:black;">
						

							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">92</div>
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center; white-space:nowrap;">
								&nbsp;
								<span style="font-size:smaller;">
								
                                    
									-
								
								&nbsp;
								</span>
								
							</div>
							
								<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">
								
									<a href="javascript://" title="Blake Evans" onclick="getScorecard(28713,3,371664,'05643A',0)">Blake Evans</a>
								
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:195px;padding:2px 2px 2px 5px; text-align:left;">  
								Morehead State 
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center">
N/A 
							</div></div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;">
								4 					
							</div>
							<div style="display:inline-block;border:1px solid silver; width:50px;padding:2px; text-align:center;"><div style="white-space:nowrap;text-align:right;width:2.5em;" align="center"> +1 </div></div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>77</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									<!--?xml version="1.0" encoding="UTF-8"?--><round_score>W</round_score> 
								</div>
							
								<div style="display:inline-block;border:1px solid silver; width:30px;padding:2px; text-align:center;">
									
											- 
										
								</div>
							
							<div style="display:inline-block;border:1px solid silver; width:40px;padding:2px; text-align:center;">
								 - 
							</div>
						</div>
						
						<div id="Player371664" style="display:none;visibility:hidden;"></div>
					
				</div>
